# %%
# !pip install huggingface_hub
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 5.0 MB/s eta 0:00:00
# ...

# %%
# !pip install -q sentencepiece
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 11.5 MB/s eta 0:00:00

# %%
# !git clone https://github.com/ggerganov/llama.cpp.git
# Out:
# Cloning into 'llama.cpp'...
# remote: Enumerating objects: 8390, done.
# remote: Counting objects: 100% (3582/3582), done.
# remote: Compressing objects: 100% (293/293), done.
# remote: Total 8390 (delta 3403), reused 3357 (delta 3289), pack-reused 4808
# Receiving objects: 100% (8390/8390), 7.85 MiB | 7.70 MiB/s, done.
# Resolving deltas: 100% (5821/5821), done.

# %%
from huggingface_hub import snapshot_download

model_id = "ingenio/llama-2-medqa-finetuned"
snapshot_download(repo_id=model_id, local_dir="/content/llama-hf",
                  local_dir_use_symlinks=False, revision="main")

snapshot_download(repo_id="meta-llama/Llama-2-7b-chat-hf", local_dir="/content/llama-ori-hf",
                  local_dir_use_symlinks=False, revision="main")
# Out:
# ...
# Fetching 16 files:   0%|          | 0/16 [00:00<?, ?it/s]
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/tqdm/contrib/concurrent.py in _executor_map(PoolExecutor, fn, *iterables, **tqdm_kwargs)
#      50                           initargs=(lk,)) as ex:
# ---> 51             return list(tqdm_class(ex.map(fn, *iterables, chunksize=chunksize), **kwargs))
#      52
#
# /usr/local/lib/python3.10/dist-packages/tqdm/notebook.py in __iter__(self)
#     248             it = super(tqdm_notebook, self).__iter__()
# --> 249             for obj in it:
#     250                 # return super(tqdm...) will not catch exception
#
# /usr/local/lib/python3.10/dist-packages/tqdm/std.py in __iter__(self)
#    1181         try:
# -> 1182             for obj in iterable:
#    1183                 yield obj
#
# ...

# %%
# !python llama.cpp/convert.py llama-hf \
  --outfile llama-2-medqa-finetuned.gguf \
  --outtype f16
# Out:
# Loading model file llama-hf/pytorch_model-00001-of-00002.bin
# Loading model file llama-hf/pytorch_model-00001-of-00002.bin
# Loading model file llama-hf/pytorch_model-00002-of-00002.bin
# params = Params(n_vocab=32000, n_embd=4096, n_mult=5504, n_layer=32, n_ctx=4096, n_ff=11008, n_head=32, n_head_kv=32, f_norm_eps=1e-06, f_rope_freq_base=None, f_rope_scale=None, ftype=<GGMLFileType.MostlyF16: 1>, path_model=PosixPath('llama-hf'))
# Loading vocab file 'llama-hf/tokenizer.model', type 'spm'
# Permuting layer 0
# Permuting layer 1
# Permuting layer 2
# Permuting layer 3
# Permuting layer 4
# Permuting layer 5
# Permuting layer 6
# Permuting layer 7
# Permuting layer 8
# Permuting layer 9
# Permuting layer 10
# Permuting layer 11
# Permuting layer 12
# Permuting layer 13
# Permuting layer 14
# Permuting layer 15
# Permuting layer 16
# Permuting layer 17
# Permuting layer 18
# Permuting layer 19
# Permuting layer 20
# Permuting layer 21
# Permuting layer 22
# Permuting layer 23
# ...

# %%
# !make -C llama.cpp -j4
# Out:
# make: Entering directory '/content/llama.cpp'
# I llama.cpp build info:
# I UNAME_S:  Linux
# I UNAME_P:  x86_64
# I UNAME_M:  x86_64
# I CFLAGS:   -I. -Icommon -DNDEBUG -DGGML_USE_K_QUANTS  -O3 -std=c11   -fPIC -Wall -Wextra -Wpedantic -Wcast-qual -Wdouble-promotion -Wshadow -Wstrict-prototypes -Wpointer-arith -Wmissing-prototypes -Werror=implicit-int -Wno-unused-function -pthread -march=native -mtune=native
# I CXXFLAGS: -I. -Icommon -DNDEBUG -DGGML_USE_K_QUANTS  -O3 -std=c++11 -fPIC -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wno-multichar -pthread -march=native -mtune=native -Wno-format-truncation
# I LDFLAGS:
# I CC:       cc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
# I CXX:      g++ (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#
# ...

# %%
! llama.cpp/quantize /content/llama-2-medqa-finetuned.gguf /content/llama-2-medqa-finetuned_q4.gguf q4_0
# Out:
# main: build = 1173 (e4386f4)
# main: quantizing '/content/llama-2-medqa-finetuned.gguf' to '/content/llama-2-medqa-finetuned_q4.gguf' as Q4_0
# llama_model_loader: loaded meta data with 18 key-value pairs and 291 tensors from /content/llama-2-medqa-finetuned.gguf (version GGUF V2 (latest))
# llama_model_loader: - tensor    0:                token_embd.weight f16      [  4096, 32000,     1,     1 ]
# llama_model_loader: - tensor    1:              blk.0.attn_q.weight f16      [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor    2:              blk.0.attn_k.weight f16      [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor    3:              blk.0.attn_v.weight f16      [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor    4:         blk.0.attn_output.weight f16      [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor    5:            blk.0.ffn_gate.weight f16      [  4096, 11008,     1,     1 ]
# ...

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     A token is already saved on your machine. Run `huggingface-cli whoami` to get more information or `huggingface-cli logout` if you want to log out.
#     Setting a new token will erase the existing one.
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) n
# Token is valid (permission: write).
# ...

# %%
from huggingface_hub import HfApi

api = HfApi()
api.upload_file(
    path_or_fileobj="/content/llama-2-medqa-finetuned_q4.gguf",
    path_in_repo="llama-2-medqa-finetuned_q4.gguf",
    repo_id="ingenio/llama-2-medqa-finetuned",
    repo_type="model",
)
# Out:
# llama-2-medqa-finetuned_q4.gguf:   0%|          | 0.00/3.83G [00:00<?, ?B/s]
# 'https://huggingface.co/ingenio/llama-2-medqa-finetuned/blob/main/llama-2-medqa-finetuned_q4.gguf'

# %%
api.upload_file(
    path_or_fileobj="/content/llama-2-medqa-finetuned.gguf",
    path_in_repo="llama-2-medqa-finetuned_f16.gguf",
    repo_id="ingenio/llama-2-medqa-finetuned",
    repo_type="model",
)
# Out:
# llama-2-medqa-finetuned.gguf:   0%|          | 0.00/13.5G [00:00<?, ?B/s]
# 'https://huggingface.co/ingenio/llama-2-medqa-finetuned/blob/main/llama-2-medqa-finetuned_f16.gguf'

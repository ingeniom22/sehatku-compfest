# %%
# !pip -q install langchain tiktoken chromadb pypdf transformers InstructorEmbedding sentence-transformers
# !pip -q install accelerate bitsandbytes==0.39.0 sentencepiece Xformers
# !pip -q install -U git+https://github.com/huggingface/peft.git
# !pip -q install -U einops==0.6.1
# !pip -q install jq
# !pip -q install llama-cpp-python

# %%
# !pip show langchain
# Out:
# Name: langchain
# Version: 0.0.247
# Summary: Building applications with LLMs through composability
# Home-page: https://www.github.com/hwchase17/langchain
# Author:
# Author-email:
# License: MIT
# Location: /opt/conda/lib/python3.10/site-packages
# Requires: aiohttp, async-timeout, dataclasses-json, langsmith, numexpr, numpy, openapi-schema-pydantic, pydantic, PyYAML, requests, SQLAlchemy, tenacity
# Required-by:

# %% [markdown]
# ## QA Retrieval No Open AI - WizardLM

# %% [markdown]
# # LangChain multi-doc retriever with ChromaDB
#
# ***New Points***
# - Multiple Files - PDFs
# - ChromaDB
# - Local LLM
# - Instuctor Embeddings

# %%
# !wget https://huggingface.co/TheBloke/Llama-2-7B-Chat-GGML/resolve/main/llama-2-7b-chat.ggmlv3.q2_K.bin
# Out:
# --2023-07-29 05:10:59--  https://huggingface.co/TheBloke/Llama-2-7B-Chat-GGML/resolve/main/llama-2-7b-chat.ggmlv3.q2_K.bin
# Resolving huggingface.co (huggingface.co)... 65.8.11.59, 65.8.11.106, 65.8.11.102, ...
# Connecting to huggingface.co (huggingface.co)|65.8.11.59|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.huggingface.co/repos/30/e3/30e3aca7233f7337633262ff6d59dd98559ecd8982e7419b39752c8d0daae1ca/45833e0b59c8fe80676c664f556031fc411da8856e0716ac7b8ed201b7221c08?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27llama-2-7b-chat.ggmlv3.q2_K.bin%3B+filename%3D%22llama-2-7b-chat.ggmlv3.q2_K.bin%22%3B&response-content-type=application%2Foctet-stream&Expires=1690866660&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qJnJlc3BvbnNlLWNvbnRlbnQtdHlwZT0qIn1dfQ__&Signature=x%7Epn6AC3tyX5PAXSNc2T2Ghqu7HESZLmXA3MBG9rOmrKOImkg3lvhh1QPN2aUQ7h96R834HYhtXBUi5tq2ScE1g43HNoPP0vafWDm3EpSxUZUCNajlkF2kDN62kMWIcS9KV90ogakOAkghH10ooHFlZfHJXBfUyBpfHW2zaKC%7Eb5VZnNQu3Z8Mm9m29SHy9ZxKyg-nIpEYqa4ccvssiTphrDgnL1DAP7baGAU1eeFbN2XW3TlFNVKy%7E81OC%7EfNgvSlV8t9RR0BfOxE7yz-mn1WxKXPRGIcjiNkwA5Yi3bwRcngPyPaw%7E5PzzHl%7E45u2u6KmqgysYcFd-KoGIPPuIwA__&Key-Pair-Id=KVTP0A1DKRTAX [following]
# --2023-07-29 05:11:00--  https://cdn-lfs.huggingface.co/repos/30/e3/30e3aca7233f7337633262ff6d59dd98559ecd8982e7419b39752c8d0daae1ca/45833e0b59c8fe80676c664f556031fc411da8856e0716ac7b8ed201b7221c08?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27llama-2-7b-chat.ggmlv3.q2_K.bin%3B+filename%3D%22llama-2-7b-chat.ggmlv3.q2_K.bin%22%3B&response-content-type=application%2Foctet-stream&Expires=1690866660&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qJnJlc3BvbnNlLWNvbnRlbnQtdHlwZT0qIn1dfQ__&Signature=x%7Epn6AC3tyX5PAXSNc2T2Ghqu7HESZLmXA3MBG9rOmrKOImkg3lvhh1QPN2aUQ7h96R834HYhtXBUi5tq2ScE1g43HNoPP0vafWDm3EpSxUZUCNajlkF2kDN62kMWIcS9KV90ogakOAkghH10ooHFlZfHJXBfUyBpfHW2zaKC%7Eb5VZnNQu3Z8Mm9m29SHy9ZxKyg-nIpEYqa4ccvssiTphrDgnL1DAP7baGAU1eeFbN2XW3TlFNVKy%7E81OC%7EfNgvSlV8t9RR0BfOxE7yz-mn1WxKXPRGIcjiNkwA5Yi3bwRcngPyPaw%7E5PzzHl%7E45u2u6KmqgysYcFd-KoGIPPuIwA__&Key-Pair-Id=KVTP0A1DKRTAX
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 65.8.11.118, 65.8.11.73, 65.8.11.95, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|65.8.11.118|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2866807424 (2.7G) [application/octet-stream]
# Saving to: ‘llama-2-7b-chat.ggmlv3.q2_K.bin’
#
# llama-2-7b-chat.ggm 100%[===================>]   2.67G  9.22MB/s    in 3m 22s
#
# 2023-07-29 05:14:23 (13.5 MB/s) - ‘llama-2-7b-chat.ggmlv3.q2_K.bin’ saved [2866807424/2866807424]

# %% [markdown]
# ## Setting up LangChain

# %%
from langchain.vectorstores import Chroma
from langchain.text_splitter import RecursiveCharacterTextSplitter

from langchain.llms import LlamaCpp

from langchain.chains import RetrievalQA
from langchain.document_loaders import TextLoader
from langchain.document_loaders import PyPDFLoader
from langchain.document_loaders import DirectoryLoader

# %% [markdown]
# ## Load multiple and process documents

# %%
from langchain.document_loaders import JSONLoader

import json
from pathlib import Path
from pprint import pprint

file_path = 'pjpi.jsonl'

def metadata_func(record: dict, metadata: dict) -> dict:
    metadata["DOI"] = record.get("DOI")
    metadata["Citation Title"] = record.get("Citation Title")
    return metadata

loader = JSONLoader(
    file_path=file_path,
    jq_schema='.',
    content_key="Abstract",
    metadata_func=metadata_func,
    json_lines=True,
)

data = loader.load()

pprint(data[:5])

# documents = loader.load()
# Out:
# [Document(page_content="Work engagement has a contribution to the success of an organization. Governmental institutions are often criticized for showing less satisfying performance and less effective services due to the misconducts of the civil servants such as coming late to work, leaving at working hours, and being less enthusiastic at work. This study aimed to examine civil servants' working conditions using three variables, namely leader-member exchange, psychological well-being, and work engagement. The measuring tools used referred to the Leader-Member Exchange Multidimensional (Liden &amp; Maslyn, 1998), Psychological Well-being Scale (Ryff, 1989) and Utrecht Work Engagement Scale (Schaufeli &amp; Bakker, 2004). There were 80 civil servants involved in this study as the subjects. They were selected using simple random sampling technique. Statistical techniques used in this study Structural Equation Modeling-Partial Least Square (SEM-PLS) with Warp PLS 5.0 Software. The result indicated that the three variables had a positive correlation with one another, and psychological well-being mediated the influence of leader-member exchange on work engagement.", metadata={'source': '/home/jupyter/pjpi.jsonl', 'seq_num': 1, 'DOI': '10.21580/pjpp.v4i1.3360', 'Citation Title': 'Leader-member exchange affects work engagement: The role of psychological well-being mediation'}),
#  Document(page_content='Housewives with HIV/AIDS are faced with internal problems because the virus continues to invade their bodies and external problems such as caring for their husbands and children infected with HIV/AIDS, stigma and discrimination, maintaining family integrity and even taking responsibility for economic problems when the husband dies. They need social support. One of the most important sources of social support is peers, especially for those who have not done open status to the family. Peer support can be obtained through Peer Support Groups (KDS) through counseling, education, and information. This qualitative research using the methodo\xadlogy approach tries to explore the social support that is obtained by housewives with HIV/AIDS through peer support groups that they participate in General Hospital Dr. Kariadi Semarang. Research involving 15 informants shows that peer support groups can provide social support for them, including information support about the treatment and development of HIV/AIDS; emotional support, self-esteem support, and network support such as intensive communication and strong friendships; and real assistance: venture capital assistance, business skills, and assistance in accessing treatment', metadata={'source': '/home/jupyter/pjpi.jsonl', 'seq_num': 2, 'DOI': '10.21580/pjpp.v4i1.3378', 'Citation Title': 'A social support for housewives with HIV/AIDS through a peer support group'}),
#  Document(page_content="Successful interpersonal communication is one of the determinants of success factors of preaching, counseling, and learning. However, the data showed that not all students can deliver effective interpersonal communication. It can be developed if students have self-concept and self-efficacy. This study aims to examine the effects of self-concept and self-efficacy on students' interpersonal communication. The subjects of this study were 342 students of the Walisongo State Islamic University of Semarang, who were selected using the cluster random sampling technique. Data were collected using three psychological scales, namely self-concept scale, self-efficacy, and effective interpersonal communication scale. Simple regression techniques and multiple regressions were used for analyzing the data. The results of the study showed that self-concept partially influenced the effectiveness of the students' interpersonal communication, contributing by 12.7%. In line with the finding, self-efficacy also has a contribution to it by 12%. Also, self-concept and self-efficacy simultaneously had contributions to the effectiveness of the students' interpersonal communication as much as 12.2%.", metadata={'source': '/home/jupyter/pjpi.jsonl', 'seq_num': 3, 'DOI': '10.21580/pjpp.v4i1.3196', 'Citation Title': 'Self concept, self efficacy, and interpersonal communication effectiveness of student'}),
#  Document(page_content="Interaction among children with their parents and peers has an important role in developing aggression in adolescents. Negative interaction can form children’s negative perception of attachment to their parents and peers. In turn, it facilitates adolescent’s negative schemes from childhood to adolescence. Negative scheme children are generally easy to get anxious, difficult to trust another person in interaction, and aggressive. This study aimed to examine the perceptions of attachment effect to their father, mother, and peer on male adolescents' aggressive behaviors. The subjects of this study were 31 adolescents aged 12-15 years old, who lived in PSMP Antasena in Magelang. They were selected through purposive sampling technique. The data were collected using aggressive behavior scale and modification of parents and peer attachment inventory. The method used for analyzing data was multiple regression. The results of the analysis showed that R=0.688, p&lt;0.01, indicating that the perceptions of father, mother and peer attachment significantly can predict aggression in male adolescents.", metadata={'source': '/home/jupyter/pjpi.jsonl', 'seq_num': 4, 'DOI': '10.21580/pjpp.v4i1.3118', 'Citation Title': 'The perception of attachment effect in parents and peers on aggressive behavior in male adolescents'}),
#  Document(page_content='This study aimed to examine parenting self-efficacy especially in mothers who have children with autism spectrum disorder and who suffer from parenting stress. They showed symptoms of anxiety and depression, which indicated parenting stress. Parenting self-efficacy is predicted to be a factor that can decrease anxiety and depression. There were 45 mothers from the city of Surabaya selected through purposive sampling technique to be the participants of this study. The data were collected through a survey using questionnaires concerning Self-efficacy for Parenting Task Index (SEPTI) and Parenting Stress Index Short Form (PSI-SF). The data analyzed using the statistical parametric of the Pearson product-moment correlation coefficient showed that the correlation coefficient was -0.424 and the significance was 0.004. It was concluded that high parenting self-efficacy of mothers who have children with autism spectrum disorder correlates with parenting stress.', metadata={'source': '/home/jupyter/pjpi.jsonl', 'seq_num': 5, 'DOI': '10.21580/pjpp.v4i1.3298', 'Citation Title': 'Self-efficacy parenting and nursing stress: Study on mother from spectrum autism children'})]

# %%
len(data)
# Out:
# 77

# %%
#splitting the text into
text_splitter = RecursiveCharacterTextSplitter(chunk_size=200, chunk_overlap=20)
texts = text_splitter.split_documents(data)

# %% [markdown]
# ## HF Instructor Embeddings

# %%
from langchain.embeddings import LlamaCppEmbeddings

llama_embeddings = LlamaCppEmbeddings(model_path="llama-2-7b-chat.ggmlv3.q2_K.bin")
# Out:
# llama.cpp: loading model from llama-2-7b-chat.ggmlv3.q2_K.bin
# llama_model_load_internal: format     = ggjt v3 (latest)
# llama_model_load_internal: n_vocab    = 32000
# llama_model_load_internal: n_ctx      = 512
# llama_model_load_internal: n_embd     = 4096
# llama_model_load_internal: n_mult     = 256
# llama_model_load_internal: n_head     = 32
# llama_model_load_internal: n_head_kv  = 32
# llama_model_load_internal: n_layer    = 32
# llama_model_load_internal: n_rot      = 128
# llama_model_load_internal: n_gqa      = 1
# llama_model_load_internal: rnorm_eps  = 1.0e-06
# llama_model_load_internal: n_ff       = 11008
# llama_model_load_internal: freq_base  = 10000.0
# llama_model_load_internal: freq_scale = 1
# llama_model_load_internal: ftype      = 10 (mostly Q2_K)
# llama_model_load_internal: model size = 7B
# llama_model_load_internal: ggml ctx size =    0.08 MB
# llama_model_load_internal: mem required  = 3035.66 MB (+  512.00 MB per state)
# llama_new_context_with_model: kv self size  =  512.00 MB
# AVX = 1 | AVX2 = 1 | AVX512 = 0 | AVX512_VBMI = 0 | AVX512_VNNI = 0 | FMA = 1 | NEON = 0 | ARM_FMA = 0 | F16C = 1 | FP16_VA = 0 | WASM_SIMD = 0 | BLAS = 0 | SSE3 = 1 | VSX = 0 |

# %% [markdown]
# ## create the DB

# %%
# Embed and store the texts
# Supplying a persist_directory will store the embeddings on disk
persist_directory = 'db'

## Here is the nmew embeddings being used
embedding = llama_embeddings

vectordb = Chroma.from_documents(
    documents=texts,
    embedding=embedding,
    persist_directory=persist_directory,
)
# Out:
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  5328.75 ms /    32 tokens (  166.52 ms per token,     6.01 tokens per second)
# llama_print_timings:        eval time =   143.53 ms /     1 runs   (  143.53 ms per token,     6.97 tokens per second)
# llama_print_timings:       total time =  5490.98 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 10137.64 ms /    44 tokens (  230.40 ms per token,     4.34 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 10164.92 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  4857.68 ms /    40 tokens (  121.44 ms per token,     8.23 tokens per second)
# llama_print_timings:        eval time =   141.46 ms /     1 runs   (  141.46 ms per token,     7.07 tokens per second)
# llama_print_timings:       total time =  5015.08 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  8906.05 ms /    72 tokens (  123.70 ms per token,     8.08 tokens per second)
# llama_print_timings:        eval time =   144.72 ms /     1 runs   (  144.72 ms per token,     6.91 tokens per second)
# llama_print_timings:       total time =  9074.97 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  4662.42 ms /    38 tokens (  122.70 ms per token,     8.15 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  4674.44 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  6226.18 ms /    51 tokens (  122.08 ms per token,     8.19 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  6242.94 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  2332.87 ms /    19 tokens (  122.78 ms per token,     8.14 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  2339.85 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  5368.03 ms /    44 tokens (  122.00 ms per token,     8.20 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  5382.75 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  5365.47 ms /    44 tokens (  121.94 ms per token,     8.20 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  5379.20 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  5565.38 ms /    44 tokens (  126.49 ms per token,     7.91 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  5579.55 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  7423.44 ms /    47 tokens (  157.95 ms per token,     6.33 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  7437.21 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  5370.44 ms /    44 tokens (  122.06 ms per token,     8.19 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  5385.56 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  4856.48 ms /    40 tokens (  121.41 ms per token,     8.24 tokens per second)
# llama_print_timings:        eval time =   143.05 ms /     1 runs   (  143.05 ms per token,     6.99 tokens per second)
# llama_print_timings:       total time =  5013.56 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  2928.75 ms /    24 tokens (  122.03 ms per token,     8.19 tokens per second)
# llama_print_timings:        eval time =   142.58 ms /     1 runs   (  142.58 ms per token,     7.01 tokens per second)
# llama_print_timings:       total time =  3080.67 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  4776.26 ms /    39 tokens (  122.47 ms per token,     8.17 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  4787.89 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  5816.09 ms /    47 tokens (  123.75 ms per token,     8.08 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  5829.78 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  5679.84 ms /    46 tokens (  123.47 ms per token,     8.10 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  5693.50 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  4637.53 ms /    38 tokens (  122.04 ms per token,     8.19 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  4649.51 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  4496.80 ms /    37 tokens (  121.54 ms per token,     8.23 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  4508.20 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  6554.97 ms /    54 tokens (  121.39 ms per token,     8.24 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  6571.50 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  3435.18 ms /    28 tokens (  122.68 ms per token,     8.15 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  3444.16 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  4734.91 ms /    39 tokens (  121.41 ms per token,     8.24 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  4746.64 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  6864.05 ms /    46 tokens (  149.22 ms per token,     6.70 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  6877.90 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  5593.69 ms /    46 tokens (  121.60 ms per token,     8.22 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  5608.03 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  6678.29 ms /    55 tokens (  121.42 ms per token,     8.24 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  6694.30 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  4632.97 ms /    38 tokens (  121.92 ms per token,     8.20 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  4644.35 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  6114.59 ms /    50 tokens (  122.29 ms per token,     8.18 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  6131.02 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  5326.86 ms /    43 tokens (  123.88 ms per token,     8.07 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  5340.28 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  5722.39 ms /    47 tokens (  121.75 ms per token,     8.21 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  5736.54 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  4841.81 ms /    40 tokens (  121.05 ms per token,     8.26 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  4853.89 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  5821.92 ms /    48 tokens (  121.29 ms per token,     8.24 tokens per second)
# llama_print_timings:        eval time =   146.46 ms /     1 runs   (  146.46 ms per token,     6.83 tokens per second)
# llama_print_timings:       total time =  5984.25 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  5835.55 ms /    48 tokens (  121.57 ms per token,     8.23 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  5849.56 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  1596.22 ms /    13 tokens (  122.79 ms per token,     8.14 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  1600.97 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  6281.63 ms /    37 tokens (  169.77 ms per token,     5.89 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  6293.21 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  5880.06 ms /    48 tokens (  122.50 ms per token,     8.16 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  5893.67 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  6453.97 ms /    53 tokens (  121.77 ms per token,     8.21 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  6470.08 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  6103.10 ms /    50 tokens (  122.06 ms per token,     8.19 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  6118.87 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  5365.78 ms /    44 tokens (  121.95 ms per token,     8.20 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  5379.77 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  4487.53 ms /    37 tokens (  121.28 ms per token,     8.25 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  4498.91 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  1955.27 ms /    16 tokens (  122.20 ms per token,     8.18 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  1959.77 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  5875.66 ms /    48 tokens (  122.41 ms per token,     8.17 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  5889.86 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  5806.41 ms /    48 tokens (  120.97 ms per token,     8.27 tokens per second)
# llama_print_timings:        eval time =   143.29 ms /     1 runs   (  143.29 ms per token,     6.98 tokens per second)
# llama_print_timings:       total time =  5966.05 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  6207.60 ms /    51 tokens (  121.72 ms per token,     8.22 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  6224.17 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  4618.96 ms /    38 tokens (  121.55 ms per token,     8.23 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  4630.14 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  6726.25 ms /    44 tokens (  152.87 ms per token,     6.54 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  6744.26 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  5159.89 ms /    36 tokens (  143.33 ms per token,     6.98 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  5172.04 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  4393.82 ms /    36 tokens (  122.05 ms per token,     8.19 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  4405.53 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  4500.64 ms /    37 tokens (  121.64 ms per token,     8.22 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  4511.87 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  4873.20 ms /    40 tokens (  121.83 ms per token,     8.21 tokens per second)
# llama_print_timings:        eval time =   142.46 ms /     1 runs   (  142.46 ms per token,     7.02 tokens per second)
# llama_print_timings:       total time =  5029.41 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  6593.49 ms /    54 tokens (  122.10 ms per token,     8.19 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  6610.54 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  5826.36 ms /    48 tokens (  121.38 ms per token,     8.24 tokens per second)
# llama_print_timings:        eval time =   144.69 ms /     1 runs   (  144.69 ms per token,     6.91 tokens per second)
# llama_print_timings:       total time =  5987.25 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  4894.39 ms /    40 tokens (  122.36 ms per token,     8.17 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  4905.76 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  2668.40 ms /    22 tokens (  121.29 ms per token,     8.24 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  2675.75 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  4818.30 ms /    40 tokens (  120.46 ms per token,     8.30 tokens per second)
# llama_print_timings:        eval time =   141.65 ms /     1 runs   (  141.65 ms per token,     7.06 tokens per second)
# llama_print_timings:       total time =  4974.24 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  5800.01 ms /    48 tokens (  120.83 ms per token,     8.28 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  5814.07 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  5670.66 ms /    47 tokens (  120.65 ms per token,     8.29 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  5684.74 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  7008.06 ms /    48 tokens (  146.00 ms per token,     6.85 tokens per second)
# llama_print_timings:        eval time =   144.09 ms /     1 runs   (  144.09 ms per token,     6.94 tokens per second)
# llama_print_timings:       total time =  7168.72 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  9488.09 ms /    72 tokens (  131.78 ms per token,     7.59 tokens per second)
# llama_print_timings:        eval time =   143.22 ms /     1 runs   (  143.22 ms per token,     6.98 tokens per second)
# llama_print_timings:       total time =  9653.95 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  3890.20 ms /    32 tokens (  121.57 ms per token,     8.23 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  3899.47 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  4898.30 ms /    40 tokens (  122.46 ms per token,     8.17 tokens per second)
# llama_print_timings:        eval time =   143.36 ms /     1 runs   (  143.36 ms per token,     6.98 tokens per second)
# llama_print_timings:       total time =  5056.04 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  4875.53 ms /    40 tokens (  121.89 ms per token,     8.20 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  4887.08 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  5444.43 ms /    44 tokens (  123.74 ms per token,     8.08 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  5457.95 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  4528.89 ms /    37 tokens (  122.40 ms per token,     8.17 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  4540.98 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  5210.48 ms /    42 tokens (  124.06 ms per token,     8.06 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  5224.36 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  2572.66 ms /    21 tokens (  122.51 ms per token,     8.16 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  2579.90 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  5169.09 ms /    42 tokens (  123.07 ms per token,     8.13 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  5183.30 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  6098.99 ms /    50 tokens (  121.98 ms per token,     8.20 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  6115.03 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  7908.21 ms /    54 tokens (  146.45 ms per token,     6.83 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  7923.82 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  5811.23 ms /    48 tokens (  121.07 ms per token,     8.26 tokens per second)
# llama_print_timings:        eval time =   207.93 ms /     1 runs   (  207.93 ms per token,     4.81 tokens per second)
# llama_print_timings:       total time =  6035.00 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  6188.90 ms /    46 tokens (  134.54 ms per token,     7.43 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  6202.43 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  4855.14 ms /    40 tokens (  121.38 ms per token,     8.24 tokens per second)
# llama_print_timings:        eval time =   141.70 ms /     1 runs   (  141.70 ms per token,     7.06 tokens per second)
# llama_print_timings:       total time =  5010.07 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =   741.38 ms /     6 tokens (  123.56 ms per token,     8.09 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =   743.64 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  4879.23 ms /    40 tokens (  121.98 ms per token,     8.20 tokens per second)
# llama_print_timings:        eval time =   142.50 ms /     1 runs   (  142.50 ms per token,     7.02 tokens per second)
# llama_print_timings:       total time =  5035.88 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  4863.58 ms /    40 tokens (  121.59 ms per token,     8.22 tokens per second)
# llama_print_timings:        eval time =   143.72 ms /     1 runs   (  143.72 ms per token,     6.96 tokens per second)
# llama_print_timings:       total time =  5021.29 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  5141.02 ms /    42 tokens (  122.41 ms per token,     8.17 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  5154.91 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  5392.92 ms /    44 tokens (  122.57 ms per token,     8.16 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  5406.80 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  5617.28 ms /    46 tokens (  122.11 ms per token,     8.19 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  5630.92 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  7566.92 ms /    62 tokens (  122.05 ms per token,     8.19 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  7585.51 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  6237.54 ms /    40 tokens (  155.94 ms per token,     6.41 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  6251.19 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  4864.08 ms /    40 tokens (  121.60 ms per token,     8.22 tokens per second)
# llama_print_timings:        eval time =   147.14 ms /     1 runs   (  147.14 ms per token,     6.80 tokens per second)
# llama_print_timings:       total time =  5024.79 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  4738.41 ms /    39 tokens (  121.50 ms per token,     8.23 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  4749.83 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  5788.47 ms /    42 tokens (  137.82 ms per token,     7.26 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  5801.92 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  4282.54 ms /    35 tokens (  122.36 ms per token,     8.17 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  4294.56 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  4646.35 ms /    38 tokens (  122.27 ms per token,     8.18 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  4658.27 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  4639.50 ms /    38 tokens (  122.09 ms per token,     8.19 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  4651.26 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  4743.70 ms /    39 tokens (  121.63 ms per token,     8.22 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  4755.15 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  4860.22 ms /    40 tokens (  121.51 ms per token,     8.23 tokens per second)
# llama_print_timings:        eval time =   142.58 ms /     1 runs   (  142.58 ms per token,     7.01 tokens per second)
# llama_print_timings:       total time =  5016.87 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  5870.29 ms /    48 tokens (  122.30 ms per token,     8.18 tokens per second)
# llama_print_timings:        eval time =   143.43 ms /     1 runs   (  143.43 ms per token,     6.97 tokens per second)
# llama_print_timings:       total time =  6029.28 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  5490.62 ms /    45 tokens (  122.01 ms per token,     8.20 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  5504.26 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  6962.61 ms /    48 tokens (  145.05 ms per token,     6.89 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  6975.89 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  5053.43 ms /    40 tokens (  126.34 ms per token,     7.92 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  5064.50 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  6225.56 ms /    51 tokens (  122.07 ms per token,     8.19 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  6241.55 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  4620.22 ms /    38 tokens (  121.58 ms per token,     8.22 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  4631.62 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  5544.13 ms /    39 tokens (  142.16 ms per token,     7.03 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  5555.74 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  4873.23 ms /    40 tokens (  121.83 ms per token,     8.21 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  4884.91 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  6104.35 ms /    50 tokens (  122.09 ms per token,     8.19 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  6120.88 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  6842.40 ms /    56 tokens (  122.19 ms per token,     8.18 tokens per second)
# llama_print_timings:        eval time =   145.02 ms /     1 runs   (  145.02 ms per token,     6.90 tokens per second)
# llama_print_timings:       total time =  7006.18 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  6106.07 ms /    50 tokens (  122.12 ms per token,     8.19 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  6122.10 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =   974.76 ms /     8 tokens (  121.84 ms per token,     8.21 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =   976.78 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  5567.04 ms /    45 tokens (  123.71 ms per token,     8.08 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  5582.78 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  6931.36 ms /    48 tokens (  144.40 ms per token,     6.93 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  6944.71 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  5787.03 ms /    47 tokens (  123.13 ms per token,     8.12 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  5801.36 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  4880.69 ms /    40 tokens (  122.02 ms per token,     8.20 tokens per second)
# llama_print_timings:        eval time =   141.81 ms /     1 runs   (  141.81 ms per token,     7.05 tokens per second)
# llama_print_timings:       total time =  5036.48 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  6111.29 ms /    50 tokens (  122.23 ms per token,     8.18 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# ...
# llama_print_timings: prompt eval time =  5169.08 ms /    42 tokens (  123.07 ms per token,     8.13 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  5183.26 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  6549.82 ms /    53 tokens (  123.58 ms per token,     8.09 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  6566.14 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  7027.32 ms /    54 tokens (  130.14 ms per token,     7.68 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  7043.08 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  7795.02 ms /    56 tokens (  139.20 ms per token,     7.18 tokens per second)
# llama_print_timings:        eval time =   151.05 ms /     1 runs   (  151.05 ms per token,     6.62 tokens per second)
# llama_print_timings:       total time =  7966.46 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  4884.82 ms /    40 tokens (  122.12 ms per token,     8.19 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  4896.74 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  1370.13 ms /    11 tokens (  124.56 ms per token,     8.03 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  1374.73 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  5282.79 ms /    43 tokens (  122.86 ms per token,     8.14 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  5296.86 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  5577.27 ms /    45 tokens (  123.94 ms per token,     8.07 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  5590.80 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  5481.89 ms /    39 tokens (  140.56 ms per token,     7.11 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  5493.74 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  5436.90 ms /    44 tokens (  123.57 ms per token,     8.09 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  5451.14 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  5910.53 ms /    48 tokens (  123.14 ms per token,     8.12 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  5923.94 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  5192.06 ms /    42 tokens (  123.62 ms per token,     8.09 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  5206.48 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  1268.52 ms /    10 tokens (  126.85 ms per token,     7.88 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  1273.34 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  6011.07 ms /    48 tokens (  125.23 ms per token,     7.99 tokens per second)
# llama_print_timings:        eval time =   147.83 ms /     1 runs   (  147.83 ms per token,     6.76 tokens per second)
# llama_print_timings:       total time =  6175.15 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  5080.70 ms /    40 tokens (  127.02 ms per token,     7.87 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  5093.97 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  8021.74 ms /    56 tokens (  143.25 ms per token,     6.98 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  8038.50 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  5725.35 ms /    46 tokens (  124.46 ms per token,     8.03 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  5739.25 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  6810.56 ms /    55 tokens (  123.83 ms per token,     8.08 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  6827.04 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  7877.98 ms /    64 tokens (  123.09 ms per token,     8.12 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  7897.42 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  7183.20 ms /    53 tokens (  135.53 ms per token,     7.38 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  7199.20 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  3562.56 ms /    29 tokens (  122.85 ms per token,     8.14 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  3571.73 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  5662.18 ms /    46 tokens (  123.09 ms per token,     8.12 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  5675.91 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  5513.22 ms /    45 tokens (  122.52 ms per token,     8.16 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  5526.69 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  5899.97 ms /    48 tokens (  122.92 ms per token,     8.14 tokens per second)
# llama_print_timings:        eval time =   148.74 ms /     1 runs   (  148.74 ms per token,     6.72 tokens per second)
# llama_print_timings:       total time =  6064.41 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  7186.27 ms /    48 tokens (  149.71 ms per token,     6.68 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  7202.41 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  7906.88 ms /    64 tokens (  123.55 ms per token,     8.09 tokens per second)
# llama_print_timings:        eval time =   146.09 ms /     1 runs   (  146.09 ms per token,     6.85 tokens per second)
# llama_print_timings:       total time =  8073.37 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  4919.87 ms /    40 tokens (  123.00 ms per token,     8.13 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  4931.54 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  1610.95 ms /    13 tokens (  123.92 ms per token,     8.07 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  1615.23 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  4939.86 ms /    40 tokens (  123.50 ms per token,     8.10 tokens per second)
# llama_print_timings:        eval time =   147.58 ms /     1 runs   (  147.58 ms per token,     6.78 tokens per second)
# llama_print_timings:       total time =  5100.88 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  6154.53 ms /    50 tokens (  123.09 ms per token,     8.12 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  6170.51 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 11810.04 ms /    51 tokens (  231.57 ms per token,     4.32 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 11838.80 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time = 26125.41 ms /    56 tokens (  466.53 ms per token,     2.14 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time = 26152.98 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  6114.48 ms /    48 tokens (  127.39 ms per token,     7.85 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  6128.09 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  8763.18 ms /    70 tokens (  125.19 ms per token,     7.99 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  8783.65 ms
#
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  2765.16 ms /    22 tokens (  125.69 ms per token,     7.96 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  2771.66 ms

# %% [markdown]
# ## Make a retriever

# %%
retriever = vectordb.as_retriever(search_kwargs={"k": 5})

# %% [markdown]
# ## Make a chain

# %%
from langchain.prompts import PromptTemplate

llm = LlamaCpp(
    model_path="llama-2-7b-chat.ggmlv3.q2_K.bin",
    input={"temperature": 0.75, "max_length": 2000, "top_p": 1},
    verbose=True,
)

# create the chain to answer questions
qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=retriever,
    return_source_documents=True,
    # chain_type_kwargs={"prompt": PROMPT}
    )
# Out:
# llama.cpp: loading model from llama-2-7b-chat.ggmlv3.q2_K.bin
# llama_model_load_internal: format     = ggjt v3 (latest)
# llama_model_load_internal: n_vocab    = 32000
# llama_model_load_internal: n_ctx      = 512
# llama_model_load_internal: n_embd     = 4096
# llama_model_load_internal: n_mult     = 256
# llama_model_load_internal: n_head     = 32
# llama_model_load_internal: n_head_kv  = 32
# llama_model_load_internal: n_layer    = 32
# llama_model_load_internal: n_rot      = 128
# llama_model_load_internal: n_gqa      = 1
# llama_model_load_internal: rnorm_eps  = 1.0e-06
# llama_model_load_internal: n_ff       = 11008
# llama_model_load_internal: freq_base  = 10000.0
# llama_model_load_internal: freq_scale = 1
# llama_model_load_internal: ftype      = 10 (mostly Q2_K)
# llama_model_load_internal: model size = 7B
# llama_model_load_internal: ggml ctx size =    0.08 MB
# llama_model_load_internal: mem required  = 3035.66 MB (+  256.00 MB per state)
# llama_new_context_with_model: kv self size  =  256.00 MB
# AVX = 1 | AVX2 = 1 | AVX512 = 0 | AVX512_VBMI = 0 | AVX512_VNNI = 0 | FMA = 1 | NEON = 0 | ARM_FMA = 0 | F16C = 1 | FP16_VA = 0 | WASM_SIMD = 0 | BLAS = 0 | SSE3 = 1 | VSX = 0 |

# %%
print(qa_chain.combine_documents_chain.llm_chain.prompt.template)
# Out:
# Use the following pieces of context to answer the question at the end. If you don't know the answer, just say that you don't know, don't try to make up an answer.
#
# {context}
#
# Question: {question}
# Helpful Answer:

# %%
## Cite sources

import textwrap

def wrap_text_preserve_newlines(text, width=110):
    # Split the input text into lines based on newline characters
    lines = text.split('\n')

    # Wrap each line individually
    wrapped_lines = [textwrap.fill(line, width=width) for line in lines]

    # Join the wrapped lines back together using newline characters
    wrapped_text = '\n'.join(wrapped_lines)

    return wrapped_text

def process_llm_response(llm_response):
    print(wrap_text_preserve_newlines(llm_response['result']))
    print('\n\nSources:')
    for source in llm_response["source_documents"]:
        print(source.metadata['Citation Title'])
        print(source.metadata['DOI'])

# %%
# full example
query = "Does work engagement has a contribution to the success of an organization?"
llm_response = qa_chain(query)
process_llm_response(llm_response)
# Out:
# llama_print_timings:        load time =  1159.31 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =  1884.92 ms /    15 tokens (  125.66 ms per token,     7.96 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =  1889.72 ms
# Llama.generate: prefix-match hit
#  Yes, I agree that work engagement is a predictor of successful outcomes.
#
#
# Sources:
# Forgiveness as a mediator on the effect of self-compassion on the ego depletion
# 10.21580/pjpp.v4i2.3814
# Resilience in health workers: The role of social support  and calling
# 10.21580/pjpp.v7i1.9287
# The effects of positive spillover and work-family conflict on female academics’ psychological well-being
# 10.21580/pjpp.v4i2.3522
# Effect of safety climate on safety behavior in employees: The mediation of safety motivation
# 10.21580/pjpp.v4i2.3346
# Pay it forward: Can perceived behavioral control to pass on scholarship aid be predicted by various narcissism?
# 10.21580/pjpp.v7i2.11768
# llama_print_timings:        load time =  1144.49 ms
# llama_print_timings:      sample time =    20.00 ms /    18 runs   (    1.11 ms per token,   899.78 tokens per second)
# llama_print_timings: prompt eval time = 31055.22 ms /   244 tokens (  127.28 ms per token,     7.86 tokens per second)
# llama_print_timings:        eval time =  2991.50 ms /    17 runs   (  175.97 ms per token,     5.68 tokens per second)
# llama_print_timings:       total time = 34192.40 ms

# %%
qa_chain.retriever.search_type , qa_chain.retriever.vectorstore

# %%
print(qa_chain.combine_documents_chain.llm_chain.prompt.template)
